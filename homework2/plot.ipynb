# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv('uber-10k.csv', header = None)
print(df)

plt.scatter(df[0], df[1])
plt.scatter([40.7923, 40.8674, 40.5934, 41.0214, 40.9552 ], [-73.9676, -73.1731, -74.467, -73.6269, -74.2396], color="red")
plt.show()
# Out:
#             0        1
# 0     40.7690 -73.9549
# 1     40.7267 -74.0345
# 2     40.7316 -73.9873
# 3     40.7588 -73.9776
# 4     40.7594 -73.9722
# ...       ...      ...
# 9995  40.7611 -73.9780
# 9996  40.7399 -74.0070
# 9997  40.7638 -73.9762
# 9998  40.7648 -73.9663
# 9999  40.7656 -73.9697
#
# [10000 rows x 2 columns]
